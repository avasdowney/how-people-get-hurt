# %%
import pandas as pd
import spacy
from spacy import displacy
import warnings
warnings.filterwarnings('ignore')
NER = spacy.load("en_core_web_sm")

# %%
df = pd.read_csv('../datasets/train.csv', encoding="latin-1")
df.head()
# Out:
#    Unnamed: 0  CPSC_Case_Number Treatment_Date  Age  Sex  Race Other_Race  \
# 0      900763       180608221.0      5/29/2018   25    1   2.0        NaN
# 1      762342       180109488.0       1/1/2018   70    2   1.0        NaN
# 2      560150       170718633.0       7/5/2017   18    1   0.0        NaN
# 3      464771       170429466.0       4/1/2017   17    2   1.0        NaN
# 4      866180       180504499.0      4/27/2018   27    1   2.0        NaN
#
#    Hispanic  Body_Part  Diagnosis  ... Fire_Involvement  Alcohol  Drug  \
# 0       NaN       35.0       71.0  ...              0.0      NaN   NaN
# 1       NaN       30.0       55.0  ...              0.0      NaN   NaN
# 2       NaN       92.0       59.0  ...              0.0      NaN   NaN
# 3       NaN       34.0       53.0  ...              0.0      NaN   NaN
# 4       NaN       35.0       64.0  ...              0.0      NaN   NaN
#
#    Product_1  Product_2  Product_3  \
# 0     3265.0        0.0        0.0
# 1      276.0        0.0        0.0
# 2     3286.0        0.0        0.0
# 3     4056.0        0.0        0.0
# 4     1267.0        0.0        0.0
#
#                                            Narrative  Stratum   PSU   Weight
# 0  25YOM PAIN TO KNEE WHEN LIFTING WEIGHTS       ...        L  42.0  55.4188
# 1  70 YOF PT STATES SHE FELL IN HER KITCHEN & HIT...        M  16.0  78.3782
# 2              18 YO M LAC FINGER-4-WHEELER ACCIDENT        V  17.0  16.1828
# 3  17 YOF A SHELF FELL ONTO PT WRIST CAUSING A CO...        C  32.0   4.7570
# 4  27 YOM HAS KNEE PX WHICH WORSENS WHILE PLAYING...        V  93.0  16.5919
#
# [5 rows x 26 columns]

# %%
def sentence_concatination(df):
    sent = ""
    for item in df["Narrative"]:
        sent += item
    return sent

# %%
result = sentence_concatination(df)
result = result.lower()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27963/3778777405.py in <module>
#       1 df.astype({'Narrative': 'str'})
# ----> 2 result = sentence_concatination(df)
#       3 result = result.lower()
#
# /tmp/ipykernel_27963/3226848191.py in sentence_concatination(df)
#       2     sent = ""
#       3     for item in df["Narrative"]:
# ----> 4         sent += item
#       5     return sent
#
# TypeError: can only concatenate str (not "float") to str

# %%
text1 = NER(result)

# %%
for word in text1.ents:
    print(word.text,word.label_)
# Out:
# 84yof CARDINAL
# four CARDINAL
# 45 CARDINAL
# four CARDINAL
# 74yom CARDINAL
# fx13yof CARDINAL
# ed c/o PERSON
# 3rd ORDINAL
# 4th ORDINAL
# 9 mo ago DATE
# keloid28 yom ORG
# first ORDINAL
# 2 days ago DATE
# ontrampoline@hm.today DATE
# 4cm QUANTITY
# 11mom CARDINAL
# l middle LOC
# strike43 PRODUCT
# about 8 CARDINAL
# trampoline park FAC
# last night TIME
# 28yof CARDINAL
# 2 days ago DATE
# arm15yof NORP
# 3 days ago DATE
# head.54yom PERSON
# 2 CARDINAL
# 35 CARDINAL
# 1cm QUANTITY
# 5yof CARDINAL
# 3 CARDINAL
# fx distal radius l buckle fx57yof ORG
# today DATE
# 5th ORDINAL
# 2 days DATE
# last week DATE
# 3 days ago DATE
# saturday DATE
# 5am TIME
# second ORDINAL
# acute knee PERSON
# laceration13 yof DATE
# lac24yof GPE
# 4 days ago DATE
# 2 weeks ago DATE
# 5th ORDINAL
# a penny MONEY
# eye.dx ORG
# hands&kneeson PERSON
# yesterday DATE
# 46yom CARDINAL
# laceration15 yo PERSON
# 6 CARDINAL
# fx l distal radius ORG
# cont l knee ORG
# 64yom CARDINAL
# this morning TIME
# 50yof CARDINAL
# bil ORG
# x4 PERSON
# 3 CARDINAL
# stairs&fell ORG
# pneumothorax19yom PERSON
# face,+loc>>chi/lac ORG
# days ago DATE
# 4 days ago DATE
# chest & head ORG
# injury49 PERSON
# 6 days DATE
# ago.dx PRODUCT
# fourth ORDINAL
# facial cont GPE
# 76 CARDINAL
# school & ORG
# 24 hour TIME
# 25mph QUANTITY
# clavicle & ORG
# 2nd DATE
# 3rd ORDINAL
# 94yof CARDINAL
# dx lac3yom PERSON
# 6 CARDINAL
# 2quart CARDINAL
# yesterday DATE
# the next day DATE
# 1369 DATE
# 17yof CARDINAL
# 2 days ago DATE
# 4 CARDINAL
# aparty & ORG
# fx91 yof PERSON
# 18 CARDINAL
# laceration29 PERSON
# today DATE
# yesterday DATE
# 1 day DATE
# 20mph QUANTITY
# 17yom CARDINAL
# concussion22yofc ORG
# ankle2yr GPE
# 3 weeks DATE
# 3 weeks ago DATE
# 55yof CARDINAL
# 50 CARDINAL
# 15 CARDINAL
# ecf s/p ORG
# hand61 ORG
# radiculopathy17yr ORG
# 330 CARDINAL
# dx scalp lac PERSON
# 76 CARDINAL
# 84yof CARDINAL
# a few days ago DATE
# all day DATE
# 38yof CARDINAL
# slipped & fell ORG
# 1 day DATE
# 7 CARDINAL
# 4th ORDINAL
# 2 feet QUANTITY
# injury.82yof PERSON
# 2nd ORDINAL
# fx nasal bones ORG
# chi63yof PERSON
# arm57yof PERSON
# homeyesterday DATE
# 20yof CARDINAL
# pelvic fx PERSON
# 3.5 CARDINAL
# yesterday DATE
# cont knee PERSON
# 5th ORDINAL
# sprain14 PERSON
# trampoline12 yof DATE
# thumb PERSON
# 71yof CARDINAL
# a few days ago DATE
# last 3 DATE
# 8 CARDINAL
# 2cm QUANTITY
# eyebrow.63yof GPE
# 3 CARDINAL
# year DATE
# 3 weeks DATE
# elbow PERSON
# knee58yf GPE
# 57yof CARDINAL
# 15 CARDINAL
# etoh.93yof PERSON
# a few days ago DATE
# wrist.12 GPE
# 2 days ago DATE
# 3 CARDINAL
# carpet& ORG
# concussion2yof ORG
# bimalleolar fx l ankle ORG
# fx l tibia.5ym t'd&f running ORG
# 2 suturesright foot QUANTITY
# 12 CARDINAL
# 38yof CARDINAL
# 2 CARDINAL
# yesterday DATE
# conj.56yof GPE
# knee46 PERSON
# last night TIME
# yesterday DATE
# 7 CARDINAL
# atv ORG
# night TIME
# fx distal radius ORG
# back>>tick ORG
# mandolin & lac finger ORG
# ed PERSON
# 63yof CARDINAL
# 5 CARDINAL
# 24yom CARDINAL
# two CARDINAL
# 3yof CARDINAL
# 12yom CARDINAL
# accidentaly PERSON
# toe15yom PERSON
# paronychia now18-yom PERSON
# injury13 yof DATE
# today DATE
# 40yof CARDINAL
# knee.78yom PERSON
# 32 CARDINAL
# glass.12yom ORG
# 1 CARDINAL
# 5 CARDINAL
# hyphema92 ORG
# accidentally PERSON
# burn22 yom PERSON
# fx50yof PRODUCT
# yesterday DATE
# 18yom CARDINAL
# 17 CARDINAL
# lac.76yof GPE
# lip38ym ytd PERSON
# today DATE
# today DATE
# 31yof CARDINAL
# pain13 mo PERSON
# 61yom CARDINAL
# 66yom CARDINAL
# fall'23 GPE
# days ago DATE
# accidentally stabbed PERSON
# inlt ORG
# 33yof CARDINAL
# hand16 yom PERSON
# 36yof CARDINAL
# 2 days ago DATE
# contusions70 yof PERSON
# 137 CARDINAL
# 45 CARDINAL
# 12th DATE
# 1 day DATE
# several days earlier DATE
# 1 CARDINAL
# 2-3 weeks DATE
# yesterday DATE
# chair&fell PERSON
# same,-loc>>chi ORG
# 2 days ago DATE
# 1 CARDINAL
# elbow4yo PERSON
# fx & nail ORG
# distal NORP
# last night TIME
# 17 CARDINAL
# two days ago DATE
# today DATE
# patella fracture3 yom PERSON
# 2-3 CARDINAL
# 17mom CARDINAL
# about 10 CARDINAL
# 5 CARDINAL
# clavicle@3yof PRODUCT
# laceration51 yf PERSON
# biba s/p fall ORG
# yesterday DATE
# 62 CARDINAL
# yesterday DATE
# 71 CARDINAL
# fracture45-yof DATE
# conjunctiva & corneal ORG
# 73 MONEY
# hematoma PERSON
# 2days ago DATE
# swelled.58yof CARDINAL
# sprain.51yof ORG
# fx ORG
# arm.55yof GPE
# a treadmill 3 days ago DATE
# 39 CARDINAL
# knife.70ym PERSON
# 3 feet QUANTITY
# concussion56 yom ORG
# n.h. GPE
# today DATE
# 1 day DATE
# 8mg QUANTITY
# balance&fell PERSON
# 25-30sec CARDINAL
# chi2yom ORG
# 2 days DATE
# 3rd ORDINAL
# yesterday DATE
# abrasion40 PERSON
# 9 CARDINAL
# max ORG
# 4 CARDINAL
# pain30yof PERSON
# gait              PERSON
# yesterday DATE
# 6 MONEY
# lac head PERSON
# 3rd & 4th ORG
# 36yom CARDINAL
# last night TIME
# 61yom CARDINAL
# home, & fell ORG
# hadupward gaze & weakness ORG
# 1 CARDINAL
# 27yof CARDINAL
# 2 weeks DATE
# laceration#55 y/o PERSON
# 9 mile QUANTITY
# laceration7wk ORG
# 1cm QUANTITY
# 15yof CARDINAL
# envenomation70 yof PERSON

# %%
displacy.render(text1,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     84yof
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  fell down a flight of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  steps and fell to the floor onto facelaceration face15yof with dislocated l knee in exercise3yf was looking out of the window @ school when fell straddling edge ofthe chair&gt;&gt;vaginal abrchi, forehead laceration.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     45
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  yom tripped and fell into a wall.4yof standing next to mom who dropped a skillet of hot bacon grease splashed up into face scald burns to face20 yof. rt ankle pain after ankle got caught on the ladder to get intothe window. dx: sprain4 yof fell off a swing. dx humerus fx45yom missed a step and fell landing on face and knee bent backwardsadmits to alcohol intake c/o knee pain, - weight bearing / knee injury54yof fell carrying grocery bags and hit head.  dx:  chi68yom walking in a grocery store when his cane was hit by a shopping cart caused a fall fractured lower arm91 yo f fell injured hip on floorfx hip13 y wf has finger laceration due to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  wheeler accidentfinger laceration, abrasion to fingerx
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     74yom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  was at home and fell out of his chair and found on floor       dx nasal
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fx13yof
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  fell off scooter riding down a hill and broke wrist.  dx:  lt wrist fx.11yom was sitting on a plastic container on a dolly when he fell off   and hit his head on concrete floor; concussion13yom presents to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ed c/o
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  cut to left small finger / mom stated pt was  playing w knife &amp; cut finger  dx laceration of finger on left hand38yom sust foot sprain when he kicked a wall*67 yom cut rt
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3rd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  digits while sharpening lawn mower blade at home dx finger laceration*18yof with earring in ear pierced
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9 mo ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , developed swelling, pain, skin discoloration; fb allergic reaction,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     keloid28 yom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  jumped into an above ground pool &amp; caught metal support bar.    dx:  pneumothorax, fx mult ribs r side, r renal cont.6yf fell bwd off the bed striking elbow&gt;&gt;pain18 mo m pulled a cup  of hot tea off of kitchen counter.               dx:  2nd deg burns face, chest, shoulder, arm.8yom fell off steps; dx contusion footl ankle spr/6yowf w/bruises
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  noticed
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 days ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  when playing
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ontrampoline@hm.today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  c/o pain after playing w/her dog&amp;tripped over him.32 yo m pt was doing yard work when he caught his forearm on th fencedx
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4cm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  laceration rt forearm101 yof fell in floor at nursing home. dx wrist fracturea
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11mom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  swallowed a rubber ear bud, fb ingestion51 yof was moving a couch which dropped onto foot.dx:
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     l middle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  phalanx shaft fx.46 yr  old female descending stairs in hotel and slipped and struck head with head
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     strike43
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  yom got up from chair and walked to stairs, fell down
# <mark class="en

# %%
def extract_entity(text, column_filter):
    result = []
    for word in text1.ents:
        #print(word.text,word.label_)
        if word.label_ == column_filter:
            result .append(word.text)
    return result

# %%
entity = extract_entity(text1, "PERSON")

# %%
entity
# Out:
# ['ed c/o',
#  'head.54yom',
#  'acute knee',
#  'hands&kneeson',
#  'laceration15 yo',
#  'x4',
#  'pneumothorax19yom',
#  'injury49',
#  'dx lac3yom',
#  'fx91 yof',
#  'laceration29',
#  'dx scalp lac',
#  'injury.82yof',
#  'chi63yof',
#  'arm57yof',
#  'pelvic fx',
#  'cont knee',
#  'sprain14',
#  'thumb',
#  'elbow',
#  'etoh.93yof',
#  'knee46',
#  'ed',
#  'accidentaly',
#  'toe15yom',
#  'paronychia now18-yom',
#  'knee.78yom',
#  'accidentally',
#  'burn22 yom',
#  'lip38ym ytd',
#  'pain13 mo',
#  'accidentally stabbed',
#  'hand16 yom',
#  'contusions70 yof',
#  'chair&fell',
#  'elbow4yo',
#  'patella fracture3 yom',
#  'laceration51 yf',
#  'hematoma',
#  'knife.70ym',
#  'balance&fell',
#  'abrasion40',
#  'pain30yof',
#  'gait             ',
#  'lac head',
#  'laceration#55 y/o',
#  'envenomation70 yof']
