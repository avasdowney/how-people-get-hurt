# %%
import pandas as pd
from sklearn import tree
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from IPython.display import Image
from six import StringIO
from sklearn.tree import export_graphviz
import pydotplus

# %%
df = pd.read_csv('../../datasets/train.csv', encoding="latin-1")
df.head()
# Out:
#    Column1  CPSC_Case_Number Treatment_Date  Age  Sex  Race Other_Race  \
# 0   900763       180608221.0      5/29/2018   25    1   2.0        NaN
# 1   762342       180109488.0       1/1/2018   70    2   1.0        NaN
# 2   560150       170718633.0       7/5/2017   18    1   0.0        NaN
# 3   464771       170429466.0       4/1/2017   17    2   1.0        NaN
# 4   866180       180504499.0      4/27/2018   27    1   2.0        NaN
#
#    Hispanic  Body_Part  Diagnosis  ... Fire_Involvement  Alcohol  Drug  \
# 0       NaN       35.0       71.0  ...              0.0      NaN   NaN
# 1       NaN       30.0       55.0  ...              0.0      NaN   NaN
# 2       NaN       92.0       59.0  ...              0.0      NaN   NaN
# 3       NaN       34.0       53.0  ...              0.0      NaN   NaN
# 4       NaN       35.0       64.0  ...              0.0      NaN   NaN
#
#    Product_1  Product_2  Product_3  \
# 0     3265.0        0.0        0.0
# 1      276.0        0.0        0.0
# 2     3286.0        0.0        0.0
# 3     4056.0        0.0        0.0
# 4     1267.0        0.0        0.0
#
#                                            Narrative  Stratum   PSU   Weight
# 0  25YOM PAIN TO KNEE WHEN LIFTING WEIGHTS       ...        L  42.0  55.4188
# 1  70 YOF PT STATES SHE FELL IN HER KITCHEN & HIT...        M  16.0  78.3782
# 2              18 YO M LAC FINGER-4-WHEELER ACCIDENT        V  17.0  16.1828
# 3  17 YOF A SHELF FELL ONTO PT WRIST CAUSING A CO...        C  32.0   4.7570
# 4  27 YOM HAS KNEE PX WHICH WORSENS WHILE PLAYING...        V  93.0  16.5919
#
# [5 rows x 26 columns]

# %%
burns = df[(df["Diagnosis"] == 57.) | (df["Diagnosis"] == 64.)]

# %%
inputs = burns.filter(["Diagnosis", "Age", "Sex","Race", "Body_Part"]).dropna()
inputs
# Out:
#         Diagnosis  Age  Sex  Race  Body_Part
# 4            64.0   27    1   2.0       35.0
# 5            57.0   84    1   1.0       81.0
# 10           64.0   33    2   1.0       30.0
# 13           57.0   34    1   1.0       82.0
# 20           57.0    7    1   0.0       83.0
# ...           ...  ...  ...   ...        ...
# 702526       57.0   28    1   1.0       82.0
# 702528       64.0   10    1   0.0       34.0
# 702529       64.0   21    1   2.0       37.0
# 702538       57.0    8    1   1.0       33.0
# 702544       64.0   13    1   1.0       89.0
#
# [201010 rows x 5 columns]

# %%
age = LabelEncoder()
sex = LabelEncoder()
race = LabelEncoder()
body_part = LabelEncoder()
inputs["age_n"] = age.fit_transform(inputs["Age"])
inputs["sex_n"] = sex.fit_transform(inputs["Sex"])
inputs["race_n"] = race.fit_transform(inputs["Race"])
inputs["body_n"] = body_part.fit_transform(inputs["Body_Part"])
inputs
# Out:
#         Diagnosis  Age  Sex  Race  Body_Part  age_n  sex_n  race_n  body_n
# 4            64.0   27    1   2.0       35.0     26      1       2       5
# 5            57.0   84    1   1.0       81.0     83      1       1      14
# 10           64.0   33    2   1.0       30.0     32      2       1       0
# 13           57.0   34    1   1.0       82.0     33      1       1      15
# 20           57.0    7    1   0.0       83.0      6      1       0      16
# ...           ...  ...  ...   ...        ...    ...    ...     ...     ...
# 702526       57.0   28    1   1.0       82.0     27      1       1      15
# 702528       64.0   10    1   0.0       34.0      9      1       0       4
# 702529       64.0   21    1   2.0       37.0     20      1       2       7
# 702538       57.0    8    1   1.0       33.0      7      1       1       3
# 702544       64.0   13    1   1.0       89.0     12      1       1      19
#
# [201010 rows x 9 columns]

# %%
target = inputs["Diagnosis"]
target
# Out:
# 4         64.0
# 5         57.0
# 10        64.0
# 13        57.0
# 20        57.0
#           ...
# 702526    57.0
# 702528    64.0
# 702529    64.0
# 702538    57.0
# 702544    64.0
# Name: Diagnosis, Length: 201010, dtype: float64

# %%
inputs_n = inputs.drop(['Diagnosis', 'Age', 'Sex', 'Race', 'Body_Part'], axis='columns')
inputs_n
# Out:
#         age_n  sex_n  race_n  body_n
# 4          26      1       2       5
# 5          83      1       1      14
# 10         32      2       1       0
# 13         33      1       1      15
# 20          6      1       0      16
# ...       ...    ...     ...     ...
# 702526     27      1       1      15
# 702528      9      1       0       4
# 702529     20      1       2       7
# 702538      7      1       1       3
# 702544     12      1       1      19
#
# [201010 rows x 4 columns]

# %%
model = tree.DecisionTreeClassifier()

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs_n, target, test_size=0.2, random_state=1) # 80% training and 20% test

# %%
X_train, xval, y_train, yval = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 60% training and 20% 20% validation

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.7787672255111686

# %%
# diagnosis = df["Diagnosis"].dropna().unique()
diagnosis = ['71', '55', '59', '53', '64', '57', '56', '51', '72', '48', '58', '62', '52',
       '74', '61', '41', '60', '63', '65', '66', '42', '68', '49', '50', '46', '69',
       '54', '47', '73', '67']

# %%
feature_cols = ["Age", "Sex", "Race", "Body_Part"]
dot_data = StringIO()
export_graphviz(model, out_file=dot_data, filled=True, rounded=True, special_characters=True,feature_names = feature_cols,
    class_names=diagnosis)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('../../outputs/demographic-breakinjury.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_28107/3398231352.py in <module>
#       3 export_graphviz(model, out_file=dot_data, filled=True, rounded=True, special_characters=True,feature_names = feature_cols,
#       4     class_names=diagnosis)
# ----> 5 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#       6 graph.write_png('../../outputs/demographic-breakinjury.png')
#       7 Image(graph.create_png())
#
# ~/.local/lib/python3.8/site-packages/pydotplus/graphviz.py in graph_from_dot_data(data)
#     300     """
#     301
# --> 302     return parser.parse_dot_data(data)
#     303
#     304
#
# ~/.local/lib/python3.8/site-packages/pydotplus/parser.py in parse_dot_data(data)
#     556             graphparser.parseWithTabs()
#     557
# --> 558         tokens = graphparser.parseString(data)
#     559
#     560         if len(tokens) == 1:
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1941             instring = instring.expandtabs()
#    1942         try:
# -> 1943             loc, tokens = self._parse(instring, 0)
#    1944             if parseAll:
#    1945                 loc = self.preParse(instring, loc)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4695         if check_ender:
#    4696             try_not_ender(instring, loc)
# -> 4697         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4698         try:
#    4699             hasIgnoreExprs = (not not self.ignoreExprs)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4067                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4068             else:
# -> 4069                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4070             if exprtokens or exprtokens.haskeys():
#    4071                 resultlist += exprtokens
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4460     def parseImpl(self, instring, loc, doActions=True):
#    4461         if self.expr is not None:
# -> 4462             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4463         else:
#    4464             raise ParseException("", loc, self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4067                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4068             else:
# -> 4069                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4070             if exprtokens or exprtokens.haskeys():
#    4071                 resultlist += exprtokens
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4847     def parseImpl(self, instring, loc, doActions=True):
#    4848         try:
# -> 4849             loc, tokens = self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4850         except (ParseException, IndexError):
#    4851             if self.defaultValue is not self.__optionalNotMatched:
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4460     def parseImpl(self, instring, loc, doActions=True):
#    4461         if self.expr is not None:
# -> 4462             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4463         else:
#    4464             raise ParseException("", loc, self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4705                 else:
#    4706                     preloc = loc
# -> 4707                 loc, tmptokens = self_expr_parse(instring, preloc, doActions)
#    4708                 if tmptokens or tmptokens.haskeys():
#    4709                     tokens += tmptokens
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4050         # pass False as last arg to _parse for first element, since we already
#    4051         # pre-parsed the string as part of our And pre-parsing
# -> 4052         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4053         errorStop = False
#    4054         for e in self.exprs[1:]:
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4252         for e in self.exprs:
#    4253             try:
# -> 4254                 ret = e._parse(instring, loc, doActions)
#    4255                 return ret
#    4256             except ParseException as err:
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4067                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4068             else:
# -> 4069                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4070             if exprtokens or exprtokens.haskeys():
#    4071                 resultlist += exprtokens
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4695         if check_ender:
#    4696             try_not_ender(instring, loc)
# -> 4697         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4698         try:
#    4699             hasIgnoreExprs = (not not self.ignoreExprs)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4067                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4068             else:
# -> 4069                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4070             if exprtokens or exprtokens.haskeys():
#    4071                 resultlist += exprtokens
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4460     def parseImpl(self, instring, loc, doActions=True):
#    4461         if self.expr is not None:
# -> 4462             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4463         else:
#    4464             raise ParseException("", loc, self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4460     def parseImpl(self, instring, loc, doActions=True):
#    4461         if self.expr is not None:
# -> 4462             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4463         else:
#    4464             raise ParseException("", loc, self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1681             if self.mayIndexError or preloc >= len(instring):
#    1682                 try:
# -> 1683                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1684                 except IndexError:
#    1685                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4252         for e in self.exprs:
#    4253             try:
# -> 4254                 ret = e._parse(instring, loc, doActions)
#    4255                 return ret
#    4256             except ParseException as err:
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1675         else:
#    1676             if callPreParse and self.callPreparse:
# -> 1677                 preloc = self.preParse(instring, loc)
#    1678             else:
#    1679                 preloc = loc
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in preParse(self, instring, loc)
#    1628     def preParse(self, instring, loc):
#    1629         if self.ignoreExprs:
# -> 1630             loc = self._skipIgnorables(instring, loc)
#    1631
#    1632         if self.skipWhitespace:
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _skipIgnorables(self, instring, loc)
#    1620                 try:
#    1621                     while 1:
# -> 1622                         loc, dummy = e._parse(instring, loc)
#    1623                         exprsFound = True
#    1624                 except ParseException:
#
# ~/.local/lib/python3.8/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1645
#    1646     # ~ @profile
# -> 1647     def _parseNoCache(self, instring, loc, doActions=True, callPreParse=True):
#    1648         TRY, MATCH, FAIL = 0, 1, 2
#    1649         debugging = (self.debug)  # and doActions)
#
# KeyboardInterrupt:
