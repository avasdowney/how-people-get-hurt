# %%
# imports needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import training dataset
data = pd.read_csv("../datasets/neiss.csv")

# Read the DataFrame, first using the feature data
features = ["CPSC_Case_Number", "Treatment_Date", "Age", "Sex",	"Race",	"Body_Part", "Diagnosis",	
    "Disposition", "Location", "Fire_Involvement", "Product_1", "Product_2", "Product_3", 
    "PSU",	"Weight"]
df = pd.DataFrame(data, columns=features)
del data

# %%
plt.hist(df[['Location']], bins=np.arange(0, 10, 1))
plt.show()

# %%
plt.hist(df[['Age']], bins = np.arange(0, 250, 10))
plt.show()

# %%
plt.hist(df[['Sex']])
plt.show()

# %%
plt.hist(df[['Diagnosis']], bins = np.arange(40, 75, 1))
plt.show()

# %%
plt.hist(df[['Disposition']], bins = np.arange(1,9,1))
plt.show()

# %%
plt.hist(df[['Body_Part']], bins = (np.arange(0, 90, 1)))
plt.show()

# %%
plt.hist(df[['Race']], bins = np.arange(0, 8, 1))
plt.show()
