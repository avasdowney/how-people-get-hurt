# %%
# imports needed
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
# import NEISS.xlsx
data = pd.read_csv("../datasets/NEISS.csv")

# Read the DataFrame, first using the feature data
features = ["CPSC_Case_Number", "Age", "Sex", "Race", "Body_Part", "Diagnosis",	
    "Disposition", "Location", "Fire_Involvement", "Product_1", "Product_2", "Product_3", 
    "PSU",	"Weight"]
df = pd.DataFrame(data, columns=features)
del data

# %%
df.head(3)
df.dtypes
# Out:
# CPSC_Case_Number      int64
# Age                   int64
# Sex                   int64
# Race                  int64
# Body_Part             int64
# Diagnosis             int64
# Disposition           int64
# Location              int64
# Fire_Involvement      int64
# Product_1             int64
# Product_2             int64
# Product_3             int64
# PSU                 float64
# Weight              float64
# dtype: object

# %%
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
# [0] signifies the index of the column we are appliying the encoding on
df = pd.DataFrame(ct.fit_transform(df).astype(str))
df.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /tmp/ipykernel_724/2040485725.py in <module>
#       1 ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
#       2 # [0] signifies the index of the column we are appliying the encoding on
# ----> 3 df = pd.DataFrame(ct.fit_transform(df).astype(str))
#       4 df.head()
#
# ~/.local/lib/python3.8/site-packages/scipy/sparse/data.py in astype(self, dtype, casting, copy)
#      70         if self.dtype != dtype:
#      71             return self._with_data(
# ---> 72                 self._deduped_data().astype(dtype, casting=casting, copy=copy),
#      73                 copy=copy)
#      74         elif copy:
#
# MemoryError: Unable to allocate 1.31 GiB for an array with shape (10989584,) and data type <U32

# %%
scaler = MinMaxScaler()
data = pd.DataFrame(scaler.fit_transform(df))
data
# Out:
#                    0         1    2         3         4         5      6   \
# 0        0.000000e+00  0.412556  0.5  0.000000  0.840426  0.484848  0.375
# 1        9.545942e-08  0.403587  0.5  0.000000  0.840426  0.484848  0.375
# 2        1.431891e-07  0.318386  1.0  0.000000  0.840426  0.484848  0.375
# 3        3.341080e-07  0.318386  1.0  0.000000  0.329787  0.696970  0.000
# 4        5.727565e-07  0.255605  0.5  0.000000  0.882979  0.545455  0.000
# ...               ...       ...  ...       ...       ...       ...    ...
# 1048568  9.999998e-01  0.062780  0.5  0.166667  0.382979  0.363636  0.000
# 1048569  9.999999e-01  0.053812  0.5  0.500000  0.393617  0.696970  0.000
# 1048570  9.999999e-01  0.098655  1.0  0.166667  0.797872  0.636364  0.000
# 1048571  1.000000e+00  0.067265  1.0  0.166667  0.329787  0.909091  0.000
# 1048572  1.000000e+00  0.058296  1.0  0.166667  0.872340  0.696970  0.000
#
#                7    8         9         10   11    12        13
# 0        0.111111  0.0  0.282964  0.325293  0.0  0.62  1.000000
# 1        0.111111  0.0  0.104163  0.000000  0.0  0.62  1.000000
# 2        0.111111  0.0  0.312672  0.000000  0.0  0.62  1.000000
# 3        0.000000  0.0  0.191087  0.000000  0.0  0.62  1.000000
# 4        0.111111  0.0  0.066385  0.000000  0.0  0.62  1.000000
# ...           ...  ...       ...       ...  ...   ...       ...
# 1048568  1.000000  0.0  0.213644  0.000000  0.0  0.07  0.004383
# 1048569  0.000000  0.0  0.202274  0.000000  0.0  0.07  0.004383
# 1048570  0.111111  0.0  0.319090  0.000000  0.0  0.07  0.004383
# 1048571  1.000000  0.0  0.213644  0.000000  0.0  0.07  0.004383
# 1048572  0.000000  0.0  0.214561  0.000000  0.0  0.07  0.004383
#
# [1048573 rows x 14 columns]

# %%
# split into train and test sets
train, test = train_test_split(df, test_size=0.33)
del df

# %%
# save train and test sets to excel files
train.to_csv("../datasets/train.csv")
test.to_csv("../datasets/test.csv")

# %%
data = pd.read_csv('../datasets/train.csv')
large, small, = train_test_split(data, test_size=0.0001)
small.to_csv("../datasets/small.csv")
